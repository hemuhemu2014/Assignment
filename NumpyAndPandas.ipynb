# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('Fitness_Tracker_Data.csv')
df=pd.DataFrame(data)
df.head()
# Out:
#    User_ID        Date  Steps  Heart_Rate_avg  Calories_Burned Workout_Type
# 0     4001  2024-01-01  14748              68              598       Cardio
# 1     4002  2024-01-02   8943              74              428       Cardio
# 2     4003  2024-01-03  14195              69              724          NaN
# 3     4004  2024-01-04   7963              97              284     Strength
# 4     4005  2024-01-05  14671              93              622         Yoga

# %%
df.shape
# Out:
# (100, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User_ID          100 non-null    int64
#  1   Date             100 non-null    object
#  2   Steps            100 non-null    int64
#  3   Heart_Rate_avg   100 non-null    int64
#  4   Calories_Burned  100 non-null    int64
#  5   Workout_Type     79 non-null     object
# dtypes: int64(4), object(2)
# memory usage: 4.8+ KB

# %%
df.isnull().sum()
# Out:
# User_ID             0
# Date                0
# Steps               0
# Heart_Rate_avg      0
# Calories_Burned     0
# Workout_Type       21
# dtype: int64

# %%
include = [col for col in df.columns if df[col].dtype in ['int64','float64']]
df[include]=df[include].fillna(df[include].mean)

# %%
df.head()
# Out:
#    User_ID        Date  Steps  Heart_Rate_avg  Calories_Burned Workout_Type
# 0     4001  2024-01-01  14748              68              598       Cardio
# 1     4002  2024-01-02   8943              74              428       Cardio
# 2     4003  2024-01-03  14195              69              724          NaN
# 3     4004  2024-01-04   7963              97              284     Strength
# 4     4005  2024-01-05  14671              93              622         Yoga

# %%
import seaborn as s
import matplotlib.pyplot as plt
plt.figure (figsize=(10,10))
df_sub=df.head(20)
s.barplot(data=df_sub,x='Steps',y='Calories_Burned')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Workout_Type', y='Heart_Rate_avg')
plt.title('Heart Rate Distribution per Workout Type')
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Steps', y='Calories_Burned', hue='Workout_Type')
plt.title('Steps vs Calories Burned by Workout Type')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric_df = df.select_dtypes(include=['number'])

plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap (Numeric Features Only)')
plt.tight_layout()
plt.show()
