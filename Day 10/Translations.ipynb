# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

# %%
tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-fr")  # Example: English to French translation
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-fr")
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/marian/tokenization_marian.py:177: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
translator = pipeline("translation", model=model, tokenizer=tokenizer)
# Out:
# Device set to use cpu

# %%
translated_text = translator("Hello, how are you?", max_length=40)[0]['translation_text']
print(translated_text)
# Out:
# Bonjour, comment allez-vous ?

# %%
tokenizer_de = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-de")  # English to German
model_de = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-de")
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/marian/tokenization_marian.py:177: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
translator_de = pipeline("translation", model=model_de, tokenizer=tokenizer_de)
# Out:
# Device set to use cpu

# %%
translated_text_de = translator_de("Hello, how are you?", max_length=40)[0]['translation_text']
print(translated_text_de)
# Out:
# Hallo, wie geht's?

# %%
tokenizer_it = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-it")  # English to Italian
model_it = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-it")
# Out:
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/789k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/814k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.35M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/models/marian/tokenization_marian.py:177: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# pytorch_model.bin:   0%|          | 0.00/343M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]

# %%
translator_it = pipeline("translation", model=model_it, tokenizer=tokenizer_it)
# Out:
# Device set to use cpu

# %%
translated_text_it = translator_it("Hello, how are you?", max_length=40)[0]['translation_text']
print(translated_text_it)
# Out:
# Ciao, come stai?
